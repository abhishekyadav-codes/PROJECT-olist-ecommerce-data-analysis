# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\olist_order_items_dataset.csv")
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_reviews=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\olist_order_reviews_dataset.csv")
df_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
df_order=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\olist_orders_dataset.csv")
df_order
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_category=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\product_category_name_translation.csv")
df_category
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
df_product=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\olist_products_dataset.csv")
df_product
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_payment=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\olist_order_payments_dataset.csv")
df_payment
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_customer=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\olist_customers_dataset.csv")
df_customer
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_seller=pd.read_csv(r"C:\Users\ABHISHEK YADAV\Downloads\olist_sellers_dataset.csv")
df_seller
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
# Q1. Total kitne orders hain?
df['order_item_id'].count()
# Out:
# np.int64(112650)

# %%
# q2. Total unique customers kitne hain?
df['order_id'].nunique()
# Out:
# 98666

# %%
# Q3. Total sellers kitne hain?
df['seller_id'].nunique()
# Out:
# 3095

# %%
# Q4. Kaun-sa order status sabse zyada hai?
df_order['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
# Q5. Kaun-si top 5 product categories sabse zyada bikti hain?
df_product['product_category_name'].value_counts().head(5)
# Out:
# product_category_name
# cama_mesa_banho          3029
# esporte_lazer            2867
# moveis_decoracao         2657
# beleza_saude             2444
# utilidades_domesticas    2335
# Name: count, dtype: int64

# %%
# Q6 .Total revenue calculate karo
df['revenue']=df['price']+df['freight_value']
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# Q7. Average order(revenue) value kya hai?
order_value=df.groupby('order_id')['revenue'].sum()
order_value.mean()
# Out:
# np.float64(160.57763809214924)

# %%
# Q8. Sabse mehenga product kaun sa hai?
df.loc[df['price'].idxmax()]
# Out:
# order_id               0812eb902a67711a1cb742b3cdaa65ae
# order_item_id                                         1
# product_id             489ae2aa008f021502940f251d4cce7f
# seller_id              e3b4998c7a498169dc7bce44e6bb6277
# shipping_limit_date                 2017-02-16 20:37:36
# price                                            6735.0
# freight_value                                    194.31
# revenue                                         6929.31
# Name: 3556, dtype: object

# %%
# Q9. Kaun-si payment type sabse zyada use hui?
df_payment['payment_type'].value_counts().head(1)
# Out:
# payment_type
# credit_card    76795
# Name: count, dtype: int64

# %%
# Q10. Review score ka average kya hai?
df_reviews['review_score'].mean()
# Out:
# np.float64(4.08642062404257)

# %%
# Q11. Monthly revenue trend nikalo.
month_trend=df.merge(df_order,on='order_id')
month_trend
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
month_trend['order_purchase_timestamp'] = pd.to_datetime(month_trend['order_purchase_timestamp'])

# %%
month_trend['month'] = month_trend['order_purchase_timestamp'].dt.month_name()
month_trend
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
a=month_trend.groupby('month')['revenue'].sum()
a
# Out:
# month
# April        1572120.28
# August       1671513.07
# December      863566.85
# February     1273189.58
# January      1244490.38
# July         1643699.65
# June         1525640.15
# March        1587175.41
# May          1735972.77
# November     1179143.77
# October       826121.21
# September     720920.12
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(20,10))
a.plot(kind='line',marker='o')
plt.xlabel('MONTHS')
plt.ylabel('REVENUE')
# Out:
# Text(0, 0.5, 'REVENUE')

# %%
# Q12. Kis month me sabse zyada orders aaye?
a=month_trend.groupby('month')['order_item_id'].sum()
a.sort_values(ascending=False)
# Out:
# month
# May          14401
# August       14392
# July         13856
# March        13352
# April        12817
# June         12589
# February     11657
# January      11066
# November     10630
# December      7352
# October       7071
# September     5753
# Name: order_item_id, dtype: int64

# %%
# Q13. Year wise growth rate calculate karo.
month_trend['year']=month_trend['order_purchase_timestamp'].dt.year

# %%
a=month_trend.groupby('year')['revenue'].sum()
a
# Out:
# year
# 2016      57183.21
# 2017    7142672.43
# 2018    8643697.60
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.bar(a.index,a.values)
plt.xlabel('YEAR')
plt.ylabel('REVENUE')
plt.show()

# %%
# Q14. Repeat customers kitne hain?
df_merge = df_order.merge(df_customer, on='customer_id')
df_merge
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
customer_orders = df_merge.groupby('customer_unique_id')['order_id'].nunique()
customer_orders
# Out:
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2    1
# 0000b849f77a49e4a4ce2b2a4ca5be3f    1
# 0000f46a3911fa3c0805444483337064    1
# 0000f6ccb0745a6a4b88665a16c9f078    1
# 0004aac84e0df4da2b147fca70cf8255    1
#                                    ..
# fffcf5a5ff07b0908bd4e2dbc735a684    1
# fffea47cd6d3cc0a88bd621562a9d061    1
# ffff371b4d645b6ecea244b27531430a    1
# ffff5962728ec6157033ef9805bacc48    1
# ffffd2657e2aad2907e67c3e9daecbeb    1
# Name: order_id, Length: 96096, dtype: int64

# %%
repeat_customers = customer_orders[customer_orders > 1]
repeat_customers
# Out:
# customer_unique_id
# 00172711b30d52eea8b313a7f2cced02    2
# 004288347e5e88a27ded2bb23747066c    2
# 004b45ec5c64187465168251cd1c9c2f    2
# 0058f300f57d7b93c477a131a59b36c3    2
# 00a39521eb40f7012db50455bf083460    2
#                                    ..
# ff36be26206fffe1eb37afd54c70e18b    3
# ff44401d0d8f5b9c54a47374eb48c1b8    2
# ff8892f7c26aa0446da53d01b18df463    2
# ff922bdd6bafcdf99cb90d7f39cea5b3    3
# ffe254cc039740e17dd15a5305035928    2
# Name: order_id, Length: 2997, dtype: int64

# %%
len(repeat_customers)
# Out:
# 2997

# %%
# Q15. Har customer ka total spending nikalo.
df1=df.merge(df_order,on='order_id')
df1
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df2=df1.merge(df_customer,on='customer_id')
df2
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
customer_spending = df2.groupby('customer_unique_id')['revenue'].sum()
customer_spending
# Out:
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2     141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f      27.19
# 0000f46a3911fa3c0805444483337064      86.22
# 0000f6ccb0745a6a4b88665a16c9f078      43.62
# 0004aac84e0df4da2b147fca70cf8255     196.89
#                                      ...
# fffcf5a5ff07b0908bd4e2dbc735a684    2067.42
# fffea47cd6d3cc0a88bd621562a9d061      84.58
# ffff371b4d645b6ecea244b27531430a     112.46
# ffff5962728ec6157033ef9805bacc48     133.69
# ffffd2657e2aad2907e67c3e9daecbeb      71.56
# Name: revenue, Length: 95420, dtype: float64

# %%
# Q16. Top 10 high spending customers kaun hain?
customer_spending.sort_values(ascending=False).head(10)
# Out:
# customer_unique_id
# 0a0a92112bd4c708ca5fde585afaa872    13664.08
# da122df9eeddfedc1dc1f5349a1a690c     7571.63
# 763c8b1c9c68a0229c42c9fc6f662b93     7274.88
# dc4802a71eae9be1dd28f5d788ceb526     6929.31
# 459bef486812aa25204be022145caa62     6922.21
# ff4159b92c40ebe40454e3e6a7c35ed6     6726.66
# 4007669dec559734d6f53e029e360987     6081.54
# 5d0a2980b292d049061542014e8960bf     4809.44
# eebb5dda148d3893cdaf5b5ca3040ccb     4764.34
# 48e1ac109decbb87765a3eade6854098     4681.78
# Name: revenue, dtype: float64

# %%
# Q17. Top 10 sellers by revenue.
seller_revenue=df.groupby('seller_id')['revenue'].sum()
seller_revenue
# Out:
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532     2748.06
# 001cca7ae9ae17fb1caed9dfb1094831    33934.17
# 001e6ad469a905060d959994f1b41e4f      267.94
# 002100f778ceb8431b7a1020ff7ab48f     2028.16
# 003554e2dce176b5555353e4f3555ac8      139.38
#                                       ...
# ffcfefa19b08742c5d315f2791395ee5       79.52
# ffdd9f82b9a447f6f8d4b91554cc7dd3     2828.66
# ffeee66ac5d5a62fe688b9d26f83f534     2259.55
# fffd5413c0700ac820c7069d66d98c89    11896.04
# ffff564a4f9085cd26170f4732393726     1770.86
# Name: revenue, Length: 3095, dtype: float64

# %%
seller_revenue.sort_values(ascending=False).head(10)
# Out:
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2    249640.70
# 7c67e1448b00f6e969d365cea6b010ab    239536.44
# 53243585a1d6dc2643021fd1853d8905    235856.68
# 4a3ca9315b744ce9f8e9374361493884    235539.96
# fa1c13f2614d7b5c4749cbc52fecda94    204084.73
# da8622b14eb17ae2831f4ac5b9dab84a    185192.32
# 7e93a43ef30c4f03f38b393420bc753a    182754.05
# 1025f0e2d44d7041d6cf58b6550e0bfa    172860.69
# 7a67c85e85bb2ce8582c35f2203ad736    162648.38
# 955fee9216a65b617aa5c0531780ce60    160602.68
# Name: revenue, dtype: float64

# %%
# Q18. Seller wise average review score.
df3=df_reviews.merge(df,on='order_id')
df3
# Out:
#                                review_id                          order_id  \
# 0       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2       80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3       228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4       e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# ...                                  ...                               ...
# 112367  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 112368  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 112369  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 112370  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 112371  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#         review_score review_comment_title  \
# ...

# %%
a=df3.groupby('seller_id')['revenue'].mean()
a
# Out:
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532    916.020000
# 001cca7ae9ae17fb1caed9dfb1094831    142.067458
# 001e6ad469a905060d959994f1b41e4f    267.940000
# 002100f778ceb8431b7a1020ff7ab48f     36.800893
# 003554e2dce176b5555353e4f3555ac8    139.380000
#                                        ...
# ffcfefa19b08742c5d315f2791395ee5     79.520000
# ffdd9f82b9a447f6f8d4b91554cc7dd3    141.433000
# ffeee66ac5d5a62fe688b9d26f83f534    161.396429
# fffd5413c0700ac820c7069d66d98c89    194.246167
# ffff564a4f9085cd26170f4732393726     88.543000
# Name: revenue, Length: 3090, dtype: float64

# %%
# Q19. Kis seller ka delivery delay sabse zyada hai?
df1['order_delivered_customer_date'] = pd.to_datetime(df1['order_delivered_customer_date'])
df1['order_estimated_delivery_date'] = pd.to_datetime(df1['order_estimated_delivery_date'])

# %%
df1['delivery_delay'] = (
    df1['order_delivered_customer_date'] -
    df1['order_estimated_delivery_date']
).dt.days
df1
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
seller_delay = df1.groupby('seller_id')['delivery_delay'].mean()
seller_delay.sort_values(ascending=False).head(1)
# Out:
# seller_id
# df683dfda87bf71ac3fc63063fba369d    167.0
# Name: delivery_delay, dtype: float64

# %%
# Q20. Delivery time calculate karo:
df1['order_purchase_timestamp'] = pd.to_datetime(df1['order_purchase_timestamp'])
df1['order_delivered_customer_date'] = pd.to_datetime(df1['order_delivered_customer_date'])

# %%
df1['delivery_time_gap'] = (df1['order_delivered_customer_date'] - df1['order_purchase_timestamp'])
df1
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# Q 21. Average delivery time kya hai?
df1['delivery_time_gap'].mean()
# Out:
# Timedelta('12 days 11:20:35.278167991')

# %%
# Q22. Kya late delivery wale orders ka review score kam hota hai?
df4=df1.merge(df_reviews,on='order_id')
df4
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112367  fffc94f6ce00a00581880bf54a75a037              1
# 112368  fffcd46ef2263f404302a634eb57f7eb              1
# 112369  fffce4705a9662cd70adb13d4a31832d              1
# 112370  fffe18544ffabc95dfada21779c9644f              1
# 112371  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df4['late_delivery'] = df4['order_delivered_customer_date'] > df4['order_estimated_delivery_date']
df4
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112367  fffc94f6ce00a00581880bf54a75a037              1
# 112368  fffcd46ef2263f404302a634eb57f7eb              1
# 112369  fffce4705a9662cd70adb13d4a31832d              1
# 112370  fffe18544ffabc95dfada21779c9644f              1
# 112371  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
a=df4.groupby('late_delivery')['review_score'].agg(['mean','count'])
a
# Out:
#                    mean   count
# late_delivery
# False          4.154820  103811
# True           2.548884    8561

# %%
plt.figure(figsize=(20,4))
a.plot(kind='line',marker='o')
# Out:
# <Axes: xlabel='late_delivery'>

# %%
 # Q23. Revenue by state (map level analysis)
revenue_state=df4.merge(df_customer, on='customer_id')
a=revenue_state.groupby('customer_state')['revenue'].sum()
a
# Out:
# customer_state
# AC      19669.70
# AL      94969.16
# AM      27650.29
# AP      16192.42
# BA     608037.39
# CE     275044.55
# DF     354435.96
# ES     312886.37
# GO     346702.09
# MA     150615.25
# MG    1847692.74
# MS     137293.30
# MT     185192.76
# PA     214062.22
# PB     139159.84
# PE     320953.96
# PI     107255.35
# PR     801348.70
# RJ    2106383.07
# RN     101242.40
# RO      57508.97
# RR      10064.62
# RS     887572.18
# SC     603368.53
# SE      71883.44
# SP    5913712.68
# TO      61266.75
# Name: revenue, dtype: float64

# %%
a=a.reset_index()
a
# Out:
#    customer_state     revenue
# 0              AC    19669.70
# 1              AL    94969.16
# 2              AM    27650.29
# 3              AP    16192.42
# 4              BA   608037.39
# 5              CE   275044.55
# 6              DF   354435.96
# 7              ES   312886.37
# 8              GO   346702.09
# 9              MA   150615.25
# 10             MG  1847692.74
# 11             MS   137293.30
# 12             MT   185192.76
# 13             PA   214062.22
# 14             PB   139159.84
# 15             PE   320953.96
# 16             PI   107255.35
# 17             PR   801348.70
# 18             RJ  2106383.07
# 19             RN   101242.40
# 20             RO    57508.97
# 21             RR    10064.62
# 22             RS   887572.18
# 23             SC   603368.53
# 24             SE    71883.44
# 25             SP  5913712.68
# 26             TO    61266.75

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(a['customer_state'], a['revenue'])

plt.xlabel('Customer State')
plt.ylabel('Total Revenue')
plt.title('Revenue by State')
plt.xticks(rotation=90)

plt.show()

# %%
# Q24. High discount products profit de rahe hain ya loss?
df4=df.merge(df_payment,on='order_id')

# %%
df4['total_cost'] = df4['price'] + df4['freight_value']
df4['discount'] = df4['total_cost'] - df4['payment_value']
df4['discount'].astype('int').inplace=True
df4
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117596  fffc94f6ce00a00581880bf54a75a037              1
# 117597  fffcd46ef2263f404302a634eb57f7eb              1
# 117598  fffce4705a9662cd70adb13d4a31832d              1
# 117599  fffe18544ffabc95dfada21779c9644f              1
# 117600  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df4[df4['discount']>0]
# Out:
#                                 order_id  order_item_id  \
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# 11      00063b381e2406b52ad429470734ebd5              1
# 15      0009792311464db532ff765bf7b182ae              1
# 18      000c3e6612759851cc3cbb4b83257986              1
# 38      0016dfedd97fc2950e388d2971d718c7              1
# ...                                  ...            ...
# 117574  ffefb169ddf34cecc0622a6d3cc387f8              1
# 117580  fff60e5408a9dd1e92ee30023052af30              1
# 117589  fffb0b1a50e65c449020434fa835e078              1
# 117598  fffce4705a9662cd70adb13d4a31832d              1
# 117599  fffe18544ffabc95dfada21779c9644f              1
#
#                               product_id                         seller_id  \
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# 11      f177554ea93259a5b282f24e33f65ab6  8602a61d680a10a82cceeeda0d99ea3d
# ...

# %%
df4['discount'].sort_values(ascending=False).head(10)
# Out:
# 72277     3899.00
# 59233     3360.66
# 60568     2442.82
# 111848    2183.41
# 77192     2073.25
# 22359     1875.77
# 107753    1816.34
# 75334     1812.71
# 48423     1800.00
# 76641     1522.42
# Name: discount, dtype: float64

# %%
# Q25. Customer segmentation:

# Low spender

# Medium spender

# High spender

df4=df.merge(df_order,on='order_id')
customer_spending=df4.groupby('customer_id')['revenue'].sum().reset_index()
customer_spending
# Out:
#                             customer_id  revenue
# 0      00012a2ce6f8dcda20d059ce98491703   114.74
# 1      000161a058600d5901f007fab4c27140    67.41
# 2      0001fd6190edaaf884bcaf3d49edf079   195.42
# 3      0002414f95344307404f0ace7a26f1d5   179.35
# 4      000379cdec625522490c315e70c7a9fb   107.01
# ...                                 ...      ...
# 98661  fffcb937e9dd47a13f05ecb8290f4d3e    91.91
# 98662  fffecc9f79fd8c764f843e9951b11341    81.36
# 98663  fffeda5b6d849fbd39689bb92087f431    63.13
# 98664  ffff42319e9b2d713724ae527742af25   214.13
# 98665  ffffa3172527f765de70084a7e53aae8    45.50
#
# [98666 rows x 2 columns]

# %%
def segment(x):
    if x<200:
        return "low spender"
    elif x<1000:
        return "medium spender"
    else:
        return "high spender"

# %%
customer_spending['segment'] = customer_spending['revenue'].apply(segment)
customer_spending
# Out:
#                             customer_id  revenue         segment
# 0      00012a2ce6f8dcda20d059ce98491703   114.74     low spender
# 1      000161a058600d5901f007fab4c27140    67.41     low spender
# 2      0001fd6190edaaf884bcaf3d49edf079   195.42     low spender
# 3      0002414f95344307404f0ace7a26f1d5   179.35     low spender
# 4      000379cdec625522490c315e70c7a9fb   107.01     low spender
# ...                                 ...      ...             ...
# 98661  fffcb937e9dd47a13f05ecb8290f4d3e    91.91     low spender
# 98662  fffecc9f79fd8c764f843e9951b11341    81.36     low spender
# 98663  fffeda5b6d849fbd39689bb92087f431    63.13     low spender
# 98664  ffff42319e9b2d713724ae527742af25   214.13  medium spender
# 98665  ffffa3172527f765de70084a7e53aae8    45.50     low spender
#
# [98666 rows x 3 columns]

# %%
customer_spending['segment'].value_counts()
# Out:
# segment
# low spender       78572
# medium spender    18946
# high spender       1148
# Name: count, dtype: int64
